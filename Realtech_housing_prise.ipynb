# %% [markdown]
# <a href="https://colab.research.google.com/github/EL-Magnific-o/Realtech_housing_prise/blob/main/Realtech_housing_prise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=zinEPDj7SD8

# %%
import keras
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df.head(20)
# Out:
#     longitude  latitude  ...  median_income  median_house_value
# 0     -114.31     34.19  ...         1.4936             66900.0
# 1     -114.47     34.40  ...         1.8200             80100.0
# 2     -114.56     33.69  ...         1.6509             85700.0
# 3     -114.57     33.64  ...         3.1917             73400.0
# 4     -114.57     33.57  ...         1.9250             65500.0
# 5     -114.58     33.63  ...         3.3438             74000.0
# 6     -114.58     33.61  ...         2.6768             82400.0
# 7     -114.59     34.83  ...         1.7083             48500.0
# 8     -114.59     33.61  ...         2.1782             58400.0
# 9     -114.60     34.83  ...         2.1908             48100.0
# 10    -114.60     33.62  ...         2.6797             86500.0
# 11    -114.60     33.60  ...         1.6250             62000.0
# 12    -114.61     34.84  ...         2.1571             48600.0
# 13    -114.61     34.83  ...         3.2120             70400.0
# ...

# %%
X = df.drop(columns=['median_house_value'])

# %%
Y =df[['median_house_value']]
Y
# Out:
#        median_house_value
# 0                 66900.0
# 1                 80100.0
# 2                 85700.0
# 3                 73400.0
# 4                 65500.0
# ...                   ...
# 16995            111400.0
# 16996             79000.0
# 16997            103600.0
# 16998             85800.0
# 16999             94600.0
#
# [17000 rows x 1 columns]

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(8, activation='relu', input_shape=(8,)))
model.add(keras.layers.Dense(8, activation='relu'))
model.add(keras.layers.Dense(1))

model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.fit(X,Y,epochs=100)
# Out:
# Epoch 1/100
# 532/532 [==============================] - 1s 1ms/step - loss: 10203449344.0000
# Epoch 2/100
# 532/532 [==============================] - 1s 1ms/step - loss: 10148579328.0000
# Epoch 3/100
# 532/532 [==============================] - 1s 1ms/step - loss: 10084671488.0000
# Epoch 4/100
# 532/532 [==============================] - 1s 1ms/step - loss: 10013920256.0000
# Epoch 5/100
# 532/532 [==============================] - 1s 1ms/step - loss: 9949752320.0000
# Epoch 6/100
# 532/532 [==============================] - 1s 1ms/step - loss: 9886974976.0000
# Epoch 7/100
# 532/532 [==============================] - 1s 1ms/step - loss: 9824577536.0000
# Epoch 8/100
# 532/532 [==============================] - 1s 1ms/step - loss: 9760313344.0000
# Epoch 9/100
# 532/532 [==============================] - 1s 1ms/step - loss: 9694357504.0000
# Epoch 10/100
# 532/532 [==============================] - 1s 1ms/step - loss: 9623033856.0000
# Epoch 11/100
# ...

# %%
#test_data_1_column = np.array([-114.60	,33.62	,16.0	,3741.0	,801.0	,2434.0	,824.0	,2.6797	])  num 10
#print(model.predict(test_data_1_column.reshape(1,8),batch_size=1))

# %%
df1 = pd.read_csv('/content/sample_data/california_housing_test.csv')

test_data = df1.drop(columns=['median_house_value'])
real_test_data = df1[['median_house_value']]

real_test_data.head(20)
# Out:
#     median_house_value
# 0             344700.0
# 1             176500.0
# 2             270500.0
# 3             330000.0
# 4              81700.0
# 5              67000.0
# 6              67000.0
# 7             166900.0
# 8             194400.0
# 9             164200.0
# 10            125000.0
# 11             58300.0
# 12            252600.0
# 13            231200.0
# 14            222500.0
# 15            153100.0
# 16            181300.0
# 17            137500.0
# 18            300000.0
# 19            414300.0

# %%
result=pd.DataFrame(model.predict(test_data,batch_size=1))
result.head(20)
# Out:
#                 0
# 0   310135.187500
# 1   180240.921875
# 2   290772.250000
# 3   266250.781250
# 4   122714.289062
# 5   120132.007812
# 6   137242.453125
# 7   138364.437500
# 8   187672.671875
# 9   135108.015625
# 10  149022.859375
# 11  126082.265625
# 12  227075.921875
# 13  192281.296875
# 14  214402.625000
# 15  169730.921875
# 16  129776.015625
# 17  164825.156250
# 18  329542.000000
# 19  342790.375000

# %%
model.save('Realtech_housing_prise.h5')

# %%
# if you want to load the model use this
#old_model = keras.models.load_model('Realtech_housing_prise.h5')
